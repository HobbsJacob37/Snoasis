# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/SnoasisJacobsVersion/blob/main/snowLV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar
day_names = [calendar.day_name[i] for i in range(0, 7)]

# Load the data into a dataframe
df = pd.read_csv('https://raw.githubusercontent.com/camdenlol/SnOasis/main/snoasisData.csv')

# Convert the 'Date' column to a datetime object
df['Date'] = pd.to_datetime(df['Date'])

# Sort the dataframe by the 'Date' column
df = df.sort_values(by='Date')

# Extract the day from the 'Date' column
df['day'] = df['Date'].dt.weekday

# Create a histogram of the 'day' column
plt.hist(df['day'], bins=range(0, 8), align='left', rwidth=0.8)

# Set the x-axis tick labels to the day names
plt.xticks(range(0, 7), day_names, rotation=45, ha='right')

# Customize the plot
plt.title('Bar Chart of Data by Day')
plt.xlabel('Day')
plt.ylabel('Sales')

# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Staff', 'Receipt number', 'Name', 'Variant', 'Unit',
#        'Quantity', 'Price (USD)', 'Discount (USD)', 'Subtotal (USD)',
#        'Tax Info Available', 'Is Tax Exempt', 'Total tax collected (USD)',
#        'Final price (USD)', 'SKU', 'Barcode', 'Cost price', 'Comment', 'day'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date        Time          Staff  Receipt number            Name  \
# 0  2023-02-28  7:50:56?PM   SnOasis Main               1       Gift card
# 12 2023-02-28  9:35:15?PM  SnOasis  East              11            Test
# 11 2023-02-28  9:34:07?PM  SnOasis  East              10  Cup of Gummies
# 10 2023-02-28  9:33:04?PM  SnOasis  East               9       Candy Bar
# 8  2023-02-28  9:31:25?PM  SnOasis  East               7       Candy Bar
#
#     Variant  Unit  Quantity  Price (USD)  Discount (USD)  Subtotal (USD)  \
# 0       NaN   NaN         1          1.0             0.0             1.0
# 12      NaN   NaN         1          5.0             0.0             5.0
# 11      NaN   NaN         1          1.5             0.0             1.5
# 10      NaN   NaN         1          1.5             0.0             1.5
# 8       NaN   NaN         1          1.5             0.0             1.5
#
#    Tax Info Available Is Tax Exempt  Total tax collected (USD)  \
# ...

# %%
dfg = df.groupby(['Date']).Quantity.sum()

dfg.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
#dfg.reset_index(inplace=True)

dfg.index
# Out:
# DatetimeIndex(['2023-02-28', '2023-03-02', '2023-03-04', '2023-03-05',
#                '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09',
#                '2023-03-10', '2023-03-11',
#                ...
#                '2023-10-20', '2023-10-21', '2023-10-22', '2023-10-23',
#                '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27',
#                '2023-11-04', '2023-11-05'],
#               dtype='datetime64[ns]', name='Date', length=236, freq=None)

# %%
allDates = dfg.index.strftime('%Y-%m-%d')

allDates
# Out:
# Index(['2023-02-28', '2023-03-02', '2023-03-04', '2023-03-05', '2023-03-06',
#        '2023-03-07', '2023-03-08', '2023-03-09', '2023-03-10', '2023-03-11',
#        ...
#        '2023-10-20', '2023-10-21', '2023-10-22', '2023-10-23', '2023-10-24',
#        '2023-10-25', '2023-10-26', '2023-10-27', '2023-11-04', '2023-11-05'],
#       dtype='object', name='Date', length=236)

# %%
# Imports
import matplotlib.pyplot as plt
import matplotlib.dates as mdates



# Drawing
fig, ax = plt.subplots(figsize=(10, 4))
plt.xlabel('Month')
plt.ylabel('Items Sold')
plt.title('SnOasis 2023')
ax.xaxis.set_major_locator(mdates.MonthLocator())
fmt = mdates.DateFormatter('%b %Y')
ax.xaxis.set_major_formatter(fmt)
ax.bar(dfg.index,dfg)
plt.setp(ax.get_xticklabels(), rotation=30);

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')
import matplotlib.pyplot as plt

# Extract month from the date column
df['month'] = df['Date'].dt.month

# Create a histogram
plt.hist(df['month'], bins=range(1, 14), align='left', rwidth=0.8)

# Customize the plot
plt.title('Bar Chart of Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
plt.xlabel('Month')
plt.ylabel('Items Sold')
plt.title('SnOasis 2023')
ax.xaxis.set_major_locator(mdates.MonthLocator())
fmt = mdates.DateFormatter('%b %Y')
ax.xaxis.set_major_formatter(fmt)
barlist = ax.bar(dfg.index,dfg)
barlist[10].set_color('r')
plt.setp(ax.get_xticklabels(), rotation=30);

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/nurfnick/SnOasis/main/SnOasisSaleDates.csv')

df2
# Out:
#            Day                                   Sale Description  \
# 0     7/3/2023                                      Free SnOcones
# 1    7/22/2023  Buy 1 get 1 of equal or lesser value for free,...
# 2    8/18/2023                                      Free Toppings
# 3     9/1/2023                                      Free SnOcones
# 4    9/17/2023  Free size upgrade and free cream topping on fa...
# 5    10/8/2023               Free toppings on pumpkin spice latte
# 6   10/17/2023  One dollar menu added for medium snOcones, top...
# 7   10/18/2023  One dollar menu added for medium snOcones, top...
# 8   10/19/2023  One dollar menu added for medium snOcones, top...
# 9   10/20/2023  One dollar menu added for medium snOcones, top...
# 10  10/21/2023  One dollar menu added for medium snOcones, top...
# 11  10/22/2023  One dollar menu added for medium snOcones, top...
# 12  10/23/2023  One dollar menu added for medium snOcones, top...
# ...

# %%
df2['Day'] = pd.to_datetime(df2.Day)

# %%
df2
# Out:
#           Day                                   Sale Description  \
# 0  2023-07-03                                      Free SnOcones
# 1  2023-07-22  Buy 1 get 1 of equal or lesser value for free,...
# 2  2023-08-18                                      Free Toppings
# 3  2023-09-01                                      Free SnOcones
# 4  2023-09-17  Free size upgrade and free cream topping on fa...
# 5  2023-10-08               Free toppings on pumpkin spice latte
# 6  2023-10-17  One dollar menu added for medium snOcones, top...
# 7  2023-10-18  One dollar menu added for medium snOcones, top...
# 8  2023-10-19  One dollar menu added for medium snOcones, top...
# 9  2023-10-20  One dollar menu added for medium snOcones, top...
# 10 2023-10-21  One dollar menu added for medium snOcones, top...
# 11 2023-10-22  One dollar menu added for medium snOcones, top...
# 12 2023-10-23  One dollar menu added for medium snOcones, top...
# ...

# %%
daylist = []
for i in df2.Day:
  daylist.append(str(i)[:10])

daylist
# Out:
# ['2023-07-03',
#  '2023-07-22',
#  '2023-08-18',
#  '2023-09-01',
#  '2023-09-17',
#  '2023-10-08',
#  '2023-10-17',
#  '2023-10-18',
#  '2023-10-19',
#  '2023-10-20',
#  '2023-10-21',
#  '2023-10-22',
#  '2023-10-23',
#  '2023-10-24',
#  '2023-10-25',
#  '2023-10-26',
#  '2023-10-27',
#  '2023-10-28',
#  '2023-10-29',
#  '2023-10-30',
#  '2023-10-31',
#  '2023-11-01',
#  '2023-11-02',
#  '2023-11-03',
#  '2023-11-04',
#  '2023-11-05',
#  '2023-10-24']

# %%
if dfg.index[-1] in daylist:
  print("yes")

# %%
df.Date
# Out:
# 0       2023-02-28
# 6       2023-02-28
# 1       2023-02-28
# 2       2023-02-28
# 4       2023-02-28
#            ...
# 76215   2023-11-05
# 76216   2023-11-05
# 76203   2023-11-05
# 76182   2023-11-05
# 76218   2023-11-05
# Name: Date, Length: 76219, dtype: datetime64[ns]

# %%
dfg.index
# Out:
# DatetimeIndex(['2023-02-28', '2023-03-02', '2023-03-04', '2023-03-05',
#                '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09',
#                '2023-03-10', '2023-03-11',
#                ...
#                '2023-10-20', '2023-10-21', '2023-10-22', '2023-10-23',
#                '2023-10-24', '2023-10-25', '2023-10-26', '2023-10-27',
#                '2023-11-04', '2023-11-05'],
#               dtype='datetime64[ns]', name='Date', length=236, freq=None)

# %%
fig, ax = plt.subplots(figsize=(10, 4))
plt.xlabel('Month')
plt.ylabel('Items Sold')
plt.title('SnOasis 2023')
ax.xaxis.set_major_locator(mdates.MonthLocator())
fmt = mdates.DateFormatter('%b %Y')
ax.xaxis.set_major_formatter(fmt)
barlist = ax.bar(dfg.index,dfg, color = 'b')


for i,d in enumerate(allDates):
  if str(d) in daylist:
    barlist[i].set_color('r')

colors = {'sale':'red', 'regular':'blue'}
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)
#ax.legend()
plt.setp(ax.get_xticklabels(), rotation=30);
